# %%
from edelweiss_data import API, QueryExpression as Q

api = API('http://localhost:8000')

dataset = api.get_published_dataset('371758f2-6a8c-4157-aba8-58fdefe0c86c', version=1)
data_frame = dataset.get_data(
  condition = None,
  aggregation_filters = {"LabelSection": ["Withdrawn"]},
  order_by = None,
  ascending = None,
)

# %%
data_frame
# Out:
#       LTKBID        LabelCompoundName  \
# 289  LT00314               nimesulide
# 290  LT00168             troglitazone
# 291  LT00045               amineptine
# 292  LT00645            trovafloxacin
# 293  LT01318                 droxicam
# 294  LT01858              tetrabamate
# 295  LT01849               ebrotidine
# 408  LT01201            chlormezanone
# 413  LT00109               iproniazid
# 414  LT00519                bromfenac
# 415  LT00131              perhexiline
# 416  LT00278            benzbromarone
# 417  LT00636               ticrynafen
# 418  LT00461  alatrofloxacin mesylate
# 419  LT02092                glafenine
# 420  LT01060                  alpidem
# 421  LT01680                pirprofen
# 422  LT00246                 pemoline
# 423  LT01611              nomifensine
# 424  LT00513             benoxaprofen
# 425  LT00560                 ibufenac
# 426  LT01219               cinchophen
# 427  LT01372                 fipexide
# 428  LT00632            sulfathiazole
# 429  LT00699           sulfacarbamide
# 430  LT00700  triacetyldiphenolisatin
# 431  LT01867            xenazoic acid
# 432  LT00686              lumiracoxib
# 433  LT02033             ximelagatran
# 434  LT01822                tolrestat
# 435  LT01574               moxisylyte
# 436  LT00690            oxyphenisatin
# 437  LT00694                clomacran
# 438  LT00696                isaxonine
# 439  LT00697               pipamazine
# 440  LT00703         phenoxypropazine
# 441  LT00691             tilbroquinol
# 442  LT01117                 bendazac
# 443  LT01120                benzarone
# 444  LT01121             benziodarone
# 445  LT01228               clometacin
# 446  LT01250               cyclofenil
# 447  LT01359                  exifone
# 448  LT01816               sulcotidil
# 449  LT01874               zimelidine
# 450  LT01508               mebanazine
# 451  LT01594                nialamide
# 452  LT01602             niperotidine
# 453  LT02110                 mepazine
# 454  LT01846           fenclozic acid
# 455  LT01854              nitrefazole
# 456  LT02449              sitaxsentan
# 457  LT02213              alaproclate
# 458  LT00692               alclofenac
#
#                                                 SMILES  ApprovalYear  \
# 289  {'original': 'CS(=O)(=O)NC1=C(C=C(C=C1)[N+](=O...           NaN
# 290  {'original': 'CC1=C(C(=C2CCC(OC2=C1C)(C)COC3=C...        1997.0
# 291  {'original': 'C1CC2=CC=CC=C2C(C3=CC=CC=C31)[NH...           NaN
# 292  {'original': 'C1[C@@H]2[C@@H](C2N)CN1C3=C(C=C4...        1997.0
# 293  {'original': 'CN1C2=C(C3=CC=CC=C3S1(=O)=O)OC(=...           NaN
# 294  {'original': 'CCCCOCC(CN1C(=O)C(C(=O)NC1=O)(CC...           NaN
# 295  {'original': 'C1=CC(=CC=C1S(=O)(=O)NC=NCCSCC2=...           NaN
# 408  {'original': 'CN1C(S(=O)(=O)CCC1=O)C2=CC=C(C=C...        1960.0
# 413  {'original': 'CC(C)NNC(=O)C1=CC=NC=C1', 'canon...           NaN
# 414  {'original': 'C1=CC(=C(C(=C1)CC(=O)O)N)C(=O)C2...        2005.0
# 415  {'original': 'C1CCC(CC1)C(CC2CCCCN2)C3CCCCC3',...           NaN
# 416  {'original': 'CCC1=C(C2=CC=CC=C2O1)C(=O)C3=CC(...           NaN
# 417  {'original': 'C1=CSC(=C1)C(=O)C2=C(C(=C(C=C2)O...           NaN
# 418  {'original': 'C[C@@H](C(=O)N[C@@H](C)C(=O)NC1[...        1997.0
# 419  {'original': 'C1=CC=C(C(=C1)C(=O)OCC(CO)O)NC2=...           NaN
# 420  {'original': 'CCCN(CCC)C(=O)CC1=C(N=C2N1C=C(C=...           NaN
# 421  {'original': 'CC(C1=CC(=C(C=C1)N2CC=CC2)Cl)C(=...           NaN
# 422  {'original': 'C1=CC=C(C=C1)C2C(=O)N=C(O2)N', '...        1975.0
# 423  {'original': 'CN1CC(C2=C(C1)C(=CC=C2)N)C3=CC=C...           NaN
# 424  {'original': 'CC(C1=CC2=C(C=C1)OC(=N2)C3=CC=C(...           NaN
# 425  {'original': 'CC(C)CC1=CC=C(C=C1)CC(=O)O', 'ca...           NaN
# 426  {'original': 'C1=CC=C(C=C1)C2=NC3=CC=CC=C3C(=C...           NaN
# 427  {'original': 'C1CN(CCN1CC2=CC3=C(C=C2)OCO3)C(=...           NaN
# 428  {'original': 'C1=CC(=CC=C1N)S(=O)(=O)NC2=NC=CS...           NaN
# 429  {'original': 'C1=CC(=CC=C1N)S(=O)(=O)NC(=O)N',...           NaN
# 430  {'original': 'CC(=O)N1C2=CC=CC=C2C(C1=O)(C3=CC...           NaN
# 431  {'original': 'CCOC(C(=O)C1=CC=C(C=C1)C2=CC=CC=...           NaN
# 432  {'original': 'CC1=CC(=C(C=C1)NC2=C(C=CC=C2Cl)F...           NaN
# 433  {'original': 'CCOC(=O)CN[C@H](C1CCCCC1)C(=O)N2...           NaN
# 434  {'original': 'CN(CC(=O)O)C(=S)C1=CC=CC2=C1C=CC...           NaN
# 435  {'original': 'CC1=CC(=C(C=C1OC(=O)C)C(C)C)OCCN...           NaN
# 436  {'original': 'CC(=O)OC1=CC=C(C=C1)C2(C3=CC=CC=...           NaN
# 437  {'original': 'CN(C)CCCC1C2=CC=CC=C2NC3=C1C=C(C...           NaN
# 438  {'original': 'CC(C)NC1=NC=CC=N1', 'canonical':...           NaN
# 439  {'original': 'C1CN(CCC1C(=O)N)CCCN2C3=CC=CC=C3...           NaN
# 440  {'original': 'CC(COC1=CC=CC=C1)NN', 'canonical...           NaN
# 441  {'original': 'CC1=CC(=C(C2=C1C=CC=N2)O)Br', 'c...           NaN
# 442  {'original': 'C1=CC=C(C=C1)CN2C3=CC=CC=C3C(=N2...           NaN
# 443  {'original': 'CCC1=C(C2=CC=CC=C2O1)C(=O)C3=CC=...           NaN
# 444  {'original': 'CCC1=C(C2=CC=CC=C2O1)C(=O)C3=CC(...           NaN
# 445  {'original': 'CC1=C(C2=C(N1CC(=O)O)C=C(C=C2)OC...           NaN
# 446  {'original': 'CC(=O)OC1=CC=C(C=C1)C(=C2CCCCC2)...           NaN
# 447  {'original': 'C1=CC(=C(C(=C1C(=O)C2=CC(=C(C(=C...           NaN
# 448  {'original': 'CCCCCCCCNC(C)C(C1=CC=C(C=C1)SC(C...           NaN
# 449  {'original': 'CN(C)CC=C(C1=CC=C(C=C1)Br)C2=CN=...           NaN
# 450  {'original': 'CC(C1=CC=CC=C1)NN', 'canonical':...           NaN
# 451  {'original': 'C1=CC=C(C=C1)CNC(=O)CCNNC(=O)C2=...           NaN
# 452  {'original': 'CN(C)CC1=CC=C(O1)CSCCN/C(=C\[N+]...           NaN
# 453  {'original': 'CN1CCCC(C1)CN2C3=CC=CC=C3SC4=CC=...           NaN
# 454  {'original': 'C1=CC(=CC=C1C2=NC(=CS2)CC(=O)O)C...           NaN
# 455  {'original': 'CC1=NC(=CN1C2=CC=C(C=C2)[N+](=O)...           NaN
# 456  {'original': 'CC1=CC2=C(C=C1CC(=O)C3=C(C=CS3)S...           NaN
# 457  {'original': 'CC(C(=O)OC(C)(C)CC1=CC=C(C=C1)Cl...           NaN
# 458  {'original': 'C=CCOC1=C(C=C(C=C1)CC(=O)O)Cl', ...           NaN
#
#     LabelSection        DILIConcern  SeverityClass AdjudicatedDILI  \
# 289    Withdrawn  Most-DILI-Concern              8             Yes
# 290    Withdrawn  Most-DILI-Concern              8             Yes
# 291    Withdrawn  Most-DILI-Concern              8             Yes
# 292    Withdrawn  Most-DILI-Concern              8             Yes
# 293    Withdrawn  Most-DILI-Concern              8             Yes
# 294    Withdrawn  Most-DILI-Concern              8             Yes
# 295    Withdrawn  Most-DILI-Concern              8             Yes
# 408    Withdrawn  Most-DILI-Concern              8             Yes
# 413    Withdrawn  Most-DILI-Concern              8            None
# 414    Withdrawn  Most-DILI-Concern              8            None
# 415    Withdrawn  Most-DILI-Concern              8            None
# 416    Withdrawn  Most-DILI-Concern              8            None
# 417    Withdrawn  Most-DILI-Concern              8            None
# 418    Withdrawn  Most-DILI-Concern              8            None
# 419    Withdrawn  Most-DILI-Concern              8            None
# 420    Withdrawn  Most-DILI-Concern              8            None
# 421    Withdrawn  Most-DILI-Concern              8            None
# 422    Withdrawn  Most-DILI-Concern              8            None
# 423    Withdrawn  Most-DILI-Concern              8            None
# 424    Withdrawn  Most-DILI-Concern              8            None
# 425    Withdrawn  Most-DILI-Concern              8            None
# 426    Withdrawn  Most-DILI-Concern              8            None
# 427    Withdrawn  Most-DILI-Concern              8            None
# 428    Withdrawn  Most-DILI-Concern              8            None
# 429    Withdrawn  Most-DILI-Concern              8            None
# 430    Withdrawn  Most-DILI-Concern              8            None
# 431    Withdrawn  Most-DILI-Concern              8            None
# 432    Withdrawn  Most-DILI-Concern              8            None
# 433    Withdrawn  Most-DILI-Concern              8            None
# 434    Withdrawn  Most-DILI-Concern              8            None
# 435    Withdrawn  Most-DILI-Concern              8            None
# 436    Withdrawn  Most-DILI-Concern              8            None
# 437    Withdrawn  Most-DILI-Concern              8            None
# 438    Withdrawn  Most-DILI-Concern              8            None
# 439    Withdrawn  Most-DILI-Concern              8            None
# 440    Withdrawn  Most-DILI-Concern              8            None
# 441    Withdrawn  Most-DILI-Concern              8            None
# 442    Withdrawn  Most-DILI-Concern              8            None
# 443    Withdrawn  Most-DILI-Concern              8            None
# 444    Withdrawn  Most-DILI-Concern              8            None
# 445    Withdrawn  Most-DILI-Concern              8            None
# 446    Withdrawn  Most-DILI-Concern              8            None
# 447    Withdrawn  Most-DILI-Concern              8            None
# 448    Withdrawn  Most-DILI-Concern              8            None
# 449    Withdrawn  Most-DILI-Concern              8            None
# 450    Withdrawn  Most-DILI-Concern              8            None
# 451    Withdrawn  Most-DILI-Concern              8            None
# 452    Withdrawn  Most-DILI-Concern              8            None
# 453    Withdrawn  Most-DILI-Concern              8            None
# 454    Withdrawn  Most-DILI-Concern              8            None
# 455    Withdrawn  Most-DILI-Concern              8            None
# 456    Withdrawn  Most-DILI-Concern              8            None
# 457    Withdrawn  Most-DILI-Concern              8            None
# 458    Withdrawn  Most-DILI-Concern              8            None
#
#            vDILIConcern Greene_Annotation Sakatis_Annotation Xu_Annotation  \
# 289  vMost-DILI-Concern                HH        Hepatotoxic      Positive
# 290  vMost-DILI-Concern                HH        Hepatotoxic      Positive
# 291  vMost-DILI-Concern                HH               None      Positive
# 292  vMost-DILI-Concern                HH               None      Positive
# 293  vMost-DILI-Concern              None               None          None
# 294  vMost-DILI-Concern              None               None          None
# 295  vMost-DILI-Concern              None               None          None
# 408  vMost-DILI-Concern              None               None          None
# 413  vMost-DILI-Concern                HH        Hepatotoxic      Positive
# 414  vMost-DILI-Concern                HH        Hepatotoxic      Positive
# 415  vMost-DILI-Concern                HH        Hepatotoxic      Positive
# 416  vMost-DILI-Concern                HH        Hepatotoxic      Positive
# 417  vMost-DILI-Concern                HH        Hepatotoxic      Positive
# 418  vMost-DILI-Concern              None               None          None
# 419  vMost-DILI-Concern                HH        Hepatotoxic      Positive
# 420  vMost-DILI-Concern                HH        Hepatotoxic      Positive
# 421  vMost-DILI-Concern                HH        Hepatotoxic      Positive
# 422  vMost-DILI-Concern                HH               None      Positive
# 423  vMost-DILI-Concern                HH               None      Positive
# 424  vMost-DILI-Concern                HH               None      Positive
# 425  vMost-DILI-Concern                HH               None      Positive
# 426  vMost-DILI-Concern                HH               None      Positive
# 427  vMost-DILI-Concern                HH               None      Positive
# 428  vMost-DILI-Concern              None               None          None
# 429  vMost-DILI-Concern              None               None          None
# 430  vMost-DILI-Concern              None               None          None
# 431  vMost-DILI-Concern              None               None          None
# 432  vMost-DILI-Concern              None               None      Positive
# 433  vMost-DILI-Concern              None               None      Positive
# 434  vMost-DILI-Concern              None               None      Positive
# 435  vMost-DILI-Concern              None               None          None
# 436  vMost-DILI-Concern              None               None          None
# 437  vMost-DILI-Concern              None               None          None
# 438  vMost-DILI-Concern              None               None          None
# 439  vMost-DILI-Concern              None               None          None
# 440  vMost-DILI-Concern              None               None          None
# 441  vMost-DILI-Concern              None               None          None
# 442  vMost-DILI-Concern              None               None          None
# 443  vMost-DILI-Concern              None               None          None
# 444  vMost-DILI-Concern              None               None          None
# 445  vMost-DILI-Concern              None               None          None
# 446  vMost-DILI-Concern              None               None          None
# 447  vMost-DILI-Concern              None               None          None
# 448  vMost-DILI-Concern              None               None          None
# 449  vMost-DILI-Concern              None               None          None
# 450  vMost-DILI-Concern              None               None          None
# 451  vMost-DILI-Concern              None               None          None
# 452  vMost-DILI-Concern              None               None          None
# 453  vMost-DILI-Concern              None               None          None
# 454  vMost-DILI-Concern              None               None          None
# 455  vMost-DILI-Concern              None               None          None
# 456  vMost-DILI-Concern              None               None          None
# 457  vMost-DILI-Concern              None               None          None
# 458  vMost-DILI-Concern              None               None          None
#
#     Zhu_Annotation                        URL (accessed on 1/21/2016)
# 289        Postive                                               None
# 290        Postive                                               None
# 291        Postive                                               None
# 292        Postive  http://dailymed.nlm.nih.gov/dailymed/drugInfo....
# 293           None                                               None
# 294           None                                               None
# 295           None                                               None
# 408        Postive                                               None
# 413        Postive                                               None
# 414        Postive                                               None
# 415        Postive                                               None
# 416        Postive                                               None
# 417        Postive                                               None
# 418        Postive                                               None
# 419           None                                               None
# 420           None                                               None
# 421           None                                               None
# 422        Postive                                               None
# 423        Postive                                               None
# 424        Postive                                               None
# 425           None                                               None
# 426           None                                               None
# 427           None                                               None
# 428           None                                               None
# 429           None                                               None
# 430           None                                               None
# 431           None                                               None
# 432        Postive                                               None
# 433           None                                               None
# 434           None                                               None
# 435        Postive                                               None
# 436           None                                               None
# 437           None                                               None
# 438           None                                               None
# 439           None                                               None
# 440           None                                               None
# 441           None                                               None
# 442           None                                               None
# 443           None                                               None
# 444           None                                               None
# 445           None                                               None
# 446           None                                               None
# 447           None                                               None
# 448           None                                               None
# 449           None                                               None
# 450           None                                               None
# 451           None                                               None
# 452           None                                               None
# 453           None                                               None
# 454           None                                               None
# 455           None                                               None
# 456           None                                               None
# 457           None                                               None
# 458           None                                               None
